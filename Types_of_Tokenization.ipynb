# %% [markdown]
# <a href="https://colab.research.google.com/github/ShlokAsthana73/NLP/blob/main/Types_of_Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Word Based Tokenization

# %%
s ="I like this course."

# %%
s.split()
# Out:
# ['I', 'like', 'this', 'course.']

# %% [markdown]
# Charachter Based Tokenization

# %%
list=[]
for char in s:
  list.append(char)
print(list)
# Out:
# ['I', ' ', 'l', 'i', 'k', 'e', ' ', 't', 'h', 'i', 's', ' ', 'c', 'o', 'u', 'r', 's', 'e', '.']

# %%
text = "".join(s.split())
text
# Out:
# 'Ilikethiscourse.'

# %%
list2=[]
for char in text:
  list2.append(char)
print(list2)
# Out:
# ['I', 'l', 'i', 'k', 'e', 't', 'h', 'i', 's', 'c', 'o', 'u', 'r', 's', 'e', '.']

# %%
str = "I am learning tokenization"

# %%
newstr = str.split()

# %%
newstr
# Out:
# ['I', 'am', 'learning', 'tokenization']

# %%
list3=[]
for word in newstr:
  if word[-3:] =='ing':
    list3.append(word.partition('ing'))
  elif word[-7:] =='ization':
    list3.append(word.partition('ization'))
  else:
    list3.append(word)
print(list3)
# Out:
# ['I', 'am', ('learn', 'ing', ''), ('token', 'ization', '')]

# %%
list4= []
for element in list3:
  if type(element) is tuple:
    list4.append(element[0])
    list4.append(element[1])
  else:
    list4.append(element)
print(list4)
# Out:
# ['I', 'am', 'learn', 'ing', 'token', 'ization']
